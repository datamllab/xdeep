# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from anchor import utils

dataset_folder = 'data/'
dataset = utils.load_dataset('adult', balance=True, dataset_folder=dataset_folder)

c = RandomForestClassifier(n_estimators=50, n_jobs=5)
c.fit(dataset.train, dataset.labels_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=5,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
import xdeep.local.perturbation.xdeep_tabular as xdeep_tabular
# %load_ext autoreload
# %autoreload 2

explainer = xdeep_tabular.TabularExplainer(c.predict_proba, ['<=50K', '>50K'], dataset.feature_names, dataset.train[0:50],
                                           categorical_features=dataset.categorical_features, categorical_names=dataset.categorical_names)
# Out:
# /anaconda3/lib/python3.6/site-packages/shap/plots/summary.py:11: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
# ...

# %%
def show_explanation(idx, dataset, labels):
    text = dataset[idx]
    print("Ground Truth:", labels[idx])

    explainer.explain('lime', text)
    explainer.show_explanation('lime')
    explainer.explain('cle', text, spans=(2,))
    explainer.show_explanation('cle')

# %%
show_explanation(0, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 1
#
# LIME Explanation
# Instance: [ 1.  4.  9.  2. 12.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.787
# Original Prediction:  0.857
#
#   Capital Gain=0       : -0.262  |  Capital Loss=0       : -0.214  |  Marital Status=Married-civ-spouse : 0.191  |
#   Hours per week=Hours per week > 45.00 : 0.123  |  Education=Bachelors  : 0.117  |  Relationship=Husband : 0.101  |
#   Occupation=Sales     : 0.039  |  Sex=Male             : 0.037  |  Race=White           : 0.033  |
#   Age=28.00 < Age <= 37.00 : 0.024  |
# CLE Explanation
# Instance: [ 1.  4.  9.  2. 12.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.766
# Original Prediction:  0.857
#
#   Capital Gain=0 AND Capital Loss=0 : -0.251  |  Marital Status=Married-civ-spouse AND Capital Gain=0 : 0.187  |  Country=United-States          : 0.151  |
# ...

# %%
show_explanation(1, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 1
#
# LIME Explanation
# Instance: [ 2.  6. 15.  2.  6.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.610
# Original Prediction:  0.191
#
#   Capital Gain=0       : -0.271  |  Capital Loss=0       : -0.208  |  Marital Status=Married-civ-spouse : 0.191  |
#   Hours per week=Hours per week > 45.00 : 0.136  |  Relationship=Husband : 0.101  |  Occupation=Handlers-cleaners : -0.086  |
#   Age=37.00 < Age <= 48.00 : 0.074  |  Workclass=Self-emp-not-inc : -0.045  |  Sex=Male             : 0.039  |
#   Education=Some-college : 0.021  |
# CLE Explanation
# Instance: [ 2.  6. 15.  2.  6.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.417
# Original Prediction:  0.191
#
#   Capital Gain=0 AND Capital Loss=0 : -0.223  |  Marital Status=Married-civ-spouse : 0.197  |  Workclass=Self-emp-not-inc AND Occupation=Handlers-cleaners : -0.131  |
# ...

# %%
show_explanation(2, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 0
#
# LIME Explanation
# Instance: [ 3.  4.  5.  2.  3.  0.  4.  1.  1.  0.  0. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.449
# Original Prediction:  0.323
#
#   Education=7th-8th    : -0.212  |  Capital Loss=0       : -0.193  |  Marital Status=Married-civ-spouse : 0.187  |
#   Hours per week=Hours per week <= 40.00 : -0.129  |  Age=Age > 48.00      : 0.102  |  Relationship=Husband : 0.097  |
#   Capital Gain=1       : 0.045  |  Sex=Male             : 0.042  |  Race=White           : 0.022  |
#   Country=United-States : 0.014  |
# CLE Explanation
# Instance: [ 3.  4.  5.  2.  3.  0.  4.  1.  1.  0.  0. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.351
# Original Prediction:  0.323
#
#   Marital Status=Married-civ-spouse : 0.171  |  Capital Loss=0                 : -0.104  |  Education=7th-8th              : -0.099  |
# ...

# %%
show_explanation(4, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 1
#
# LIME Explanation
# Instance: [ 2.  4. 12.  2.  4.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.852
# Original Prediction:  1.000
#
#   Capital Gain=0       : -0.284  |  Capital Loss=0       : -0.200  |  Marital Status=Married-civ-spouse : 0.184  |
#   Hours per week=Hours per week > 45.00 : 0.121  |  Relationship=Husband : 0.100  |  Occupation=Exec-managerial : 0.081  |
#   Age=37.00 < Age <= 48.00 : 0.081  |  Education=Masters    : 0.077  |  Sex=Male             : 0.032  |
#   Race=White           : 0.025  |
# CLE Explanation
# Instance: [ 2.  4. 12.  2.  4.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.884
# Original Prediction:  1.000
#
#   Capital Gain=0 AND Capital Loss=0 : -0.207  |  Education=Masters AND Occupation=Exec-managerial : 0.158  |  Marital Status=Married-civ-spouse : 0.117  |
# ...

# %%
show_explanation(5, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 1
#
# LIME Explanation
# Instance: [ 3.  4. 10.  2. 10.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.932
# Original Prediction:  0.914
#
#   Capital Gain=0       : -0.244  |  Marital Status=Married-civ-spouse : 0.186  |  Capital Loss=0       : -0.185  |
#   Education=Doctorate  : 0.129  |  Hours per week=Hours per week > 45.00 : 0.126  |  Age=Age > 48.00      : 0.112  |
#   Relationship=Husband : 0.103  |  Occupation=Prof-specialty : 0.093  |  Sex=Male             : 0.036  |
#   Race=White           : 0.026  |
# CLE Explanation
# Instance: [ 3.  4. 10.  2. 10.  0.  4.  1.  0.  0.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.829
# Original Prediction:  0.914
#
#   Capital Gain=0 AND Capital Loss=0 : -0.230  |  Marital Status=Married-civ-spouse : 0.173  |  Relationship=Husband           : 0.101  |
# ...

# %%
show_explanation(6, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 1
#
# LIME Explanation
# Instance: [ 2.  4.  7.  0.  3.  1.  4.  1.  0.  2.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.640
# Original Prediction:  0.900
#
#   Capital Gain=0       : -0.267  |  Capital Loss=2       : 0.191  |  Hours per week=Hours per week > 45.00 : 0.125  |
#   Marital Status=Divorced : -0.103  |  Relationship=Not-in-family : -0.080  |  Age=37.00 < Age <= 48.00 : 0.078  |
#   Sex=Male             : 0.028  |  Race=White           : 0.013  |  Education=Assoc-acdm : 0.011  |
#   Workclass=Private    : -0.007  |
# CLE Explanation
# Instance: [ 2.  4.  7.  0.  3.  1.  4.  1.  0.  2.  2. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.808
# Original Prediction:  0.900
#
#   Capital Gain=0                 : -0.219  |  Capital Gain=0 AND Capital Loss=2 : 0.159  |  Education=Assoc-acdm AND Capital Loss=2 : 0.091  |
# ...

# %%
show_explanation(7, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 0
#
# LIME Explanation
# Instance: [ 3.  4. 11.  2.  3.  0.  4.  1.  0.  0.  0. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.514
# Original Prediction:  0.579
#
#   Capital Gain=0       : -0.260  |  Capital Loss=0       : -0.222  |  Marital Status=Married-civ-spouse : 0.194  |
#   Hours per week=Hours per week <= 40.00 : -0.145  |  Relationship=Husband : 0.106  |  Age=Age > 48.00      : 0.094  |
#   Education=HS-grad    : -0.084  |  Sex=Male             : 0.035  |  Race=White           : 0.031  |
#   Workclass=Private    : -0.009  |
# CLE Explanation
# Instance: [ 3.  4. 11.  2.  3.  0.  4.  1.  0.  0.  0. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.554
# Original Prediction:  0.579
#
#   Marital Status=Married-civ-spouse : 0.177  |  Capital Gain=0 AND Capital Loss=0 : -0.158  |  Capital Gain=0                 : -0.112  |
# ...

# %%
show_explanation(8, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 0
#
# LIME Explanation
# Instance: [ 1.  4. 11.  3.  8.  1.  4.  0.  0.  0.  0. 10.]
#
# Explanation for label >50K:
# Local Prediction:     0.060
# Original Prediction:  0.140
#
#   Capital Gain=0       : -0.237  |  Capital Loss=0       : -0.168  |  Marital Status=Married-spouse-absent : -0.146  |
#   Hours per week=Hours per week <= 40.00 : -0.144  |  Occupation=Other-service : -0.110  |  Relationship=Not-in-family : -0.102  |
#   Country=France       : 0.080  |  Education=HS-grad    : -0.077  |  Sex=Female           : -0.033  |
#   Race=White           : 0.031  |
# CLE Explanation
# Instance: [ 1.  4. 11.  3.  8.  1.  4.  0.  0.  0.  0. 10.]
#
# Explanation for label >50K:
# Local Prediction:     0.147
# Original Prediction:  0.140
#
#   Marital Status=Married-spouse-absent : -0.066  |  Marital Status=Married-spouse-absent AND Capital Loss=0 : -0.066  |  Occupation=Other-service       : -0.045  |
# ...

# %%
show_explanation(9, dataset.test, dataset.labels_test)
# Out:
# Ground Truth: 0
#
# LIME Explanation
# Instance: [ 2.  2.  7.  2. 13.  0.  4.  1.  0.  0.  1. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.786
# Original Prediction:  0.760
#
#   Capital Gain=0       : -0.265  |  Marital Status=Married-civ-spouse : 0.200  |  Capital Loss=0       : -0.189  |
#   Hours per week=40.00 < Hours per week <= 45.00 : 0.116  |  Relationship=Husband : 0.109  |  Age=37.00 < Age <= 48.00 : 0.078  |
#   Workclass=Local-gov  : 0.038  |  Occupation=Tech-support : 0.031  |  Sex=Male             : 0.027  |
#   Race=White           : 0.023  |
# CLE Explanation
# Instance: [ 2.  2.  7.  2. 13.  0.  4.  1.  0.  0.  1. 39.]
#
# Explanation for label >50K:
# Local Prediction:     0.748
# Original Prediction:  0.760
#
#   Marital Status=Married-civ-spouse : 0.199  |  Capital Gain=0 AND Capital Loss=0 : -0.193  |  Capital Loss=0 AND Hours per week=40.00 < Hours per week <= 45.00 : 0.071  |
# ...
